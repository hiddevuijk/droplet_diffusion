# %%
import matplotlib.pyplot as plt
import matplotlib.animation as anim
import numpy as np

# %%
ti = 0

c0 = np.loadtxt("data/c_"+str(ti) + ".dat").T
drops0 = np.loadtxt("data/drops_" + str(ti) + ".dat")

Lx = 50
Ly = 25
Nx = 100
Ny = 50

dx = Lx / Nx
dy = Ly / Ny
aspect = dy / dx


fig = plt.figure()

ax1  = fig.add_axes([0.1, 0.075, 0.85, 0.3])
ax0  = fig.add_axes([0.1, 0.475, 0.85, 0.3])
axcb = fig.add_axes([0.1, 0.875, 0.85, 0.05])


ax = ax0
im = ax.imshow(c0, interpolation='none', origin='lower')
ax.set_title("concentration")


fig.colorbar(im, cax=axcb, orientation='horizontal')
ax.set_aspect(aspect)

ax = ax1
ax.set_title("Droplets")

ax.set_xlim([0,Lx])
ax.set_ylim([0,Ly])
ax.set_aspect(1)

for i in range(drops.shape[0]):
    x = drops0[i][0]
    y = drops0[i][1]
    R = drops0[i][2]

    if R > 0:
        #print(x,y,R)
        circle = plt.Circle((x, y), R) 
        circle.set_alpha(0.3) 
        ax.add_artist(circle)


 
plt.show()
